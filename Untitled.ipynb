# %% [markdown]
# # Testing the rendering of jupyter notebooks with voilá
#
# The gaussian distribution is defined as follows:
# $$ \mathrm{gauss}(x) = I_0 \cdot \exp \left( -\frac{x^2}{\sigma^2} \right) $$

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact
from IPython.display import display

# %%
x = np.linspace(-3, 3, 100)
y = np.exp(-x**2/2)
plt.plot(x, y)
plt.show()

# %%
output = widgets.Output()
with output:
    display(widgets.Button(description = 'My Button'))
display(output)
# Out:
# Output()

# %% [markdown]
# where is my button?

# %%
def func1(x):
    return 5*x

# %%
interact(func1, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %%
import serial

# %%
ser = serial.Serial('COM3', 9600, timeout=1)

# %%
for i in range(10):
    print(ser.readline())
# Out:
# b'A\r\n'

# %%
ser.close()
